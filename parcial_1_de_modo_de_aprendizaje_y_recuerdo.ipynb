# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanPTM18/parcial-redes-neuronales/blob/main/parcial_1_de_modo_de_aprendizaje_y_recuerdo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 1 :modo de aprendizaje(entrenamiento de red neuronal)

# %%
import tensorflow as tf # contruye y entrena redes neuronales
from tensorflow import keras

# Cargar el dataset MNIST
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

#normalizar los datos(escala de 0 a 1)
x_train, x_test= x_train/255.0,x_test/255.0

#definir la red neuronal
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),#capa de entrada
    keras.layers.Dense(128,activation='relu'),#capa oculta
    keras.layers.Dense(10, activation='softmax')#capa de salida
])

#compilar el modelo(modo de aprendizaje)
model.compile(optimizer='adam',# es un optimizador
              loss='sparse_categorical_crossentropy',#para clasificacion
              metrics=['accuracy'])
#entrada red neuronal
print("modo de aprendizaje: entrenando la red neuronal...")
model.fit(x_train, y_train, epochs=5,validation_data=(x_test,y_test))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# modo de aprendizaje: entrenando la red neuronal...
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8769 - loss: 0.4336 - val_accuracy: 0.9614 - val_loss: 0.1323
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9652 - loss: 0.1202 - val_accuracy: 0.9665 - val_loss: 0.1050
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9775 - loss: 0.0770 - val_accuracy: 0.9758 - val_loss: 0.0791
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9833 - loss: 0.0570 - val_accuracy: 0.9768 - val_loss: 0.0789
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9873 - loss: 0.0414 - val_accuracy: 0.9770 - val_loss: 0.0743

# %% [markdown]
# Cambio 1

# %%
import tensorflow as tf # contruye y entrena redes neuronales
from tensorflow import keras

# Cargar el dataset MNIST
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

#normalizar los datos(escala de 0 a 1)
x_train, x_test= x_train/255.0,x_test/255.0

#definir la red neuronal
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),#capa de entrada
    keras.layers.Dense(128,activation='relu'),#capa oculta
    keras.layers.Dense(10, activation='softmax')#capa de salida
])

#compilar el modelo(modo de aprendizaje)
model.compile(optimizer='adam',# es un optimizador
              loss='sparse_categorical_crossentropy',#para clasificacion
              metrics=['accuracy'])
model.fit(x_train,y_train,epochs=3)
test_loss,test_acc=model.evaluate(x_test,y_test)
print(f'precision en el conjunto de prueba:{test_acc:.4f}')#.4 es que quede con 4 decimales
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8765 - loss: 0.4287
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9668 - loss: 0.1164
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9762 - loss: 0.0769
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9706 - loss: 0.0988
# precision en el conjunto de prueba:0.9737

# %% [markdown]
# Cambio 2

# %%
# Importar las bibliotecas necesarias
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt  # Para visualizar las imágenes

# Cargar y preparar los datos de MNIST
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalizar los datos (valores entre 0 y 1)
x_train = x_train / 255.0
x_test = x_test / 255.0

# Mostrar algunas imágenes de ejemplo
plt.figure(figsize=(10, 5))  # Tamaño de la figura
for i in range(10):  # Mostrar 10 imágenes
    plt.subplot(2, 5, i+1)  # Organizar en 2 filas y 5 columnas
    plt.imshow(x_train[i], cmap='gray')  # Mostrar la imagen en escala de grises
    plt.title(f'Dígito: {y_train[i]}')  # Título con la etiqueta real
    plt.axis('off')  # Quitar ejes
plt.show()  # Mostrar todas las imágenes

# Crear un modelo simple
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),  # Aplanar las imágenes de 28x28 a un vector
    layers.Dense(128, activation='relu'),  # Capa densa con 128 neuronas
    layers.Dense(10, activation='softmax') # Capa de salida con 10 clases
])

# Compilar el modelo
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Entrenar el modelo
model.fit(x_train, y_train, epochs=3)

# Evaluar el modelo
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Precisión en el conjunto de prueba: {test_acc:.4f}')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8760 - loss: 0.4296
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9662 - loss: 0.1177
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9763 - loss: 0.0770
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9687 - loss: 0.1018
# Precisión en el conjunto de prueba: 0.9722

# %% [markdown]
# ejercicio 2: modelo de recuerdo (inferencia o prediccion)

# %%
# Importar las bibliotecas necesarias
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt  # Para visualizar las imágenes

# Cargar y preparar los datos de MNIST
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalizar los datos (valores entre 0 y 1)
x_train = x_train / 255.0
x_test = x_test / 255.0

# Mostrar algunas imágenes de ejemplo
plt.figure(figsize=(10, 5))  # Tamaño de la figura
for i in range(10):  # Mostrar 10 imágenes
    plt.subplot(2, 5, i+1)  # Organizar en 2 filas y 5 columnas
    plt.imshow(x_train[i], cmap='gray')  # Mostrar la imagen en escala de grises
    plt.title(f'Dígito: {y_train[i]}')  # Título con la etiqueta real
    plt.axis('off')  # Quitar ejes
plt.show()  # Mostrar todas las imágenes

# Crear un modelo con memoria (LSTM)
model = models.Sequential([
    layers.Input(shape=(28, 28)),  #28 pasos de tiempo(filas),28 caracteristicas
    layers.LSTM(128, return_sequences=False),  # capa LSTM con 128 neuronas
    layers.Dense(10, activation='softmax') # Capa de salida con 10 clases
])
# Compilar el modelo
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
#resumen del modelo
model.summary()
# Entrenar el modelo
model.fit(x_train, y_train, epochs=3)

# Evaluar el modelo
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f'Precisión en el conjunto de prueba: {test_acc:.4f}')
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 128)                 │          80,384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 81,674 (319.04 KB)
#  Trainable params: 81,674 (319.04 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.7806 - loss: 0.6415
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9667 - loss: 0.1151
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9772 - loss: 0.0739
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9762 - loss: 0.0794
# Precisión en el conjunto de prueba: 0.9819

# %% [markdown]
# ejercicio 3 elegir el digito especifico que quiere predecir

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt
import numpy as np


(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()


x_train = x_train / 255.0
x_test = x_test / 255.0


model = models.Sequential([
    layers.Input(shape=(28, 28)),
    layers.SimpleRNN(64),
    layers.Dense(10, activation='softmax')
])


model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

print("Entrenando el modelo..")
model.fit(x_train, y_train, epochs=3, verbose=1)

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print(f"\nPrecision en el conjunto de prueba: {test_acc:.4f}")

digito_deseado = 4

indice = None
for i in range(len(x_test)):
  if y_test[i] == digito_deseado:
    indice = i
    break

if indice is not None:
  imagen_prueba = x_test[indice]
  etiqueta_real = y_test[indice]

  plt.figure(figsize=(5, 5))
  plt.imshow(imagen_prueba, cmap='gray')
  plt.title(f'imagen seleccionada - Etiqueta real: {etiqueta_real}')
  plt.axis('off')
  plt.show()

  imagen_prueba_reshape = np.expand_dims(imagen_prueba, axis=0)
  prediccion = model.predict(imagen_prueba_reshape, verbose=0)
  digito_predicho = np.argmax(prediccion)

  print(f"\nPrediccion del modelo: {digito_predicho}")
  print("Probabilidades para cada clase: ")
  for i, prob in enumerate(prediccion[0]):
    print(f"Clase {i}: {prob:.4f}")

  # Comparar el resultado con la etiqueta real
  print(f"\nEtiqueta real: {etiqueta_real}")
  if digito_predicho == etiqueta_real:
    print("El modelo acertó en su predicción")
  else:
    print("El modelo falló en su predicción.")

  plt.figure(figsize=(5, 5))
  plt.imshow(imagen_prueba, cmap='gray')
  plt.text(2, 2, f'Pred: {digito_predicho}', color='red', fontsize=12, weight='bold',
           bbox=dict(facecolor='white', alpha=0.8))
  plt.text(2, 25, f'Real: {etiqueta_real}', color='blue', fontsize=12, weight='bold',
           bbox=dict(facecolor='white', alpha=0.8))
  plt.axis('off')
  plt.show()

else:
  print(f"No se encontró ninguna imagen con el digito {digito_deseado} en el conjunto de prueba.")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Entrenando el modelo..
# Epoch 1/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.7312 - loss: 0.8307
# Epoch 2/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9238 - loss: 0.2608
# Epoch 3/3
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 5ms/step - accuracy: 0.9420 - loss: 0.2037
#
# Precision en el conjunto de prueba: 0.9458
# Prediccion del modelo: 4
# Probabilidades para cada clase:
# Clase 0: 0.0000
# Clase 1: 0.0000
# Clase 2: 0.0000
# Clase 3: 0.0000
# Clase 4: 0.9959
# Clase 5: 0.0001
# Clase 6: 0.0000
# Clase 7: 0.0001
# Clase 8: 0.0001
# Clase 9: 0.0038
#
# Etiqueta real: 4
# El modelo acertó en su predicción
